# %%
import graphviz
D = graphviz.Digraph()
for i in range(1, 8):
    D.node(str(i))
D.edges(['12', '31', '34', '53',])
D.attr(constraint = 'false')
D.edges(['23', '45'])

# %%
D

# %%
E = graphviz.Digraph()

E.edges(['12', '34'])

# %%
E

# %%
F = graphviz.Digraph()
F.edge('A', 'B')
F.edge('A', 'C')
F.edge('B', 'C', constraint = 'false')
F

# %%
D = graphviz.Digraph()
for i in range(1, 8):
    D.node(str(i))
D.edges(['12', '34', '65'])
D.attr('edge', constraint = 'false')
D.edges(['23', '45', '31', '53', '76', '57'])
D

# %%
D.edge('2', '3', color = 'red')
D
